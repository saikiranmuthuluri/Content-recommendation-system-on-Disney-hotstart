# %% [markdown]
# <a href="https://colab.research.google.com/github/saikiranmuthuluri/Content-recommendation-system-on-Disney-hotstart/blob/main/DIsneyplus_reccomendation_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/disney_plus_titles.csv")
df.head(10)
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
# 5      s6    Movie                                 Becoming Cousteau
# 6      s7  TV Show                                           Hawkeye
# 7      s8  TV Show                            Port Protection Alaska
# 8      s9  TV Show                         Secrets of the Zoo: Tampa
# 9     s10    Movie             A Muppets Christmas: Letters To Santa
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
# 5                         Liz Garbus
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                   Kirk R. Thatcher
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...            NaN
# 1           Jim Varney, Noelle Parker, Douglas Seale            NaN
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...            NaN
# 4  John Lennon, Paul McCartney, George Harrison, ...            NaN
# 5              Jacques Yves Cousteau, Vincent Cassel  United States
# 6  Jeremy Renner, Hailee Steinfeld, Vera Farmiga,...            NaN
# 7  Gary Muehlberger, Mary Miller, Curly Leach, Sa...  United States
# 8  Dr. Ray Ball, Dr. Lauren Smith, Chris Massaro,...  United States
# 9  Steve Whitmire, Dave Goelz, Bill Barretta, Eri...  United States
#
#           date_added  release_year rating   duration  \
# 0  November 26, 2021          2016   TV-G     23 min
# 1  November 26, 2021          1988     PG     91 min
# 2  November 26, 2021          2011   TV-G     23 min
# 3  November 26, 2021          2021  TV-PG     41 min
# 4  November 25, 2021          2021    NaN   1 Season
# 5  November 24, 2021          2021  PG-13     94 min
# 6  November 24, 2021          2021  TV-14   1 Season
# 7  November 24, 2021          2015  TV-14  2 Seasons
# 8  November 24, 2021          2019  TV-PG  2 Seasons
# 9  November 19, 2021          2008      G     45 min
#
#                               listed_in  \
# 0                     Animation, Family
# 1                                Comedy
# 2             Animation, Comedy, Family
# 3                               Musical
# 4         Docuseries, Historical, Music
# 5             Biographical, Documentary
# 6           Action-Adventure, Superhero
# 7         Docuseries, Reality, Survival
# 8  Animals & Nature, Docuseries, Family
# 9               Comedy, Family, Musical
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...
# 5  An inside look at the legendary life of advent...
# 6  Clint Barton/Hawkeye must team up with skilled...
# 7  Residents of Port Protection must combat volat...
# 8  A day in the life at ZooTampa is anything but ...
# 9  Celebrate the holiday season with all your fav...

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])
df['date_added'] = df['date_added'].fillna(df['date_added'].mode()[0])
df['rating'] = df['rating'].fillna(df['country'].mode()[0])

# %%
df.isna().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        473
# cast            190
# country           0
# date_added        0
# release_year      0
# rating            0
# duration          0
# listed_in         0
# description       0
# dtype: int64

# %%
import missingno
missingno.bar(df,fontsize=10,figsize=(10,5))
plt.title('missing values in each column',fontsize=20)
# Out:
# Text(0.5, 1.0, 'missing values in each column')

# %%
df['country'] = df['country'].fillna(df['country'].mode()[0])
df['date_added'] = df['date_added'].fillna(df['date_added'].mode()[0])
df['rating'] = df['rating'].fillna(df['country'].mode()[0])

# %%
df = df.dropna( how='any',subset=['cast', 'director'])

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Rename the 'listed_in' column as 'Genre' for easy understanding
df = df.rename(columns={"listed_in":"Genre"})
df['Genre'] = df['Genre'].apply(lambda x: x.split(",")[0])
df['Genre'].head()
# Out:
# 0       Animation
# 1          Comedy
# 2       Animation
# 3         Musical
# 5    Biographical
# Name: Genre, dtype: object

# %%
#renaming the column name date added
df['year_add'] = df['date_added'].apply(lambda x: x.split(" ")[-1])
df['year_add'].head()
# Out:
# 0    2021
# 1    2021
# 2    2021
# 3    2021
# 5    2021
# Name: year_add, dtype: object

# %%
#renaming country
df['country_main'] = df['country'].apply(lambda x: x.split(",")[0])
df['country_main'].head()
# Out:
# 0    United States
# 1    United States
# 2    United States
# 3    United States
# 5    United States
# Name: country_main, dtype: object

# %%
df['type'].value_counts()
# Out:
# type
# Movie    880
# Name: count, dtype: int64

# %%
df['rating'].value_counts()
# Out:
# rating
# G                234
# PG               229
# TV-G             166
# TV-PG            134
# PG-13             66
# TV-14             21
# TV-Y7             21
# TV-Y7-FV           5
# TV-Y               3
# United States      1
# Name: count, dtype: int64

# %%
movie_df = df[df['type'] == 'Movie']
tv_df = df[df['type'] == 'TV Show']

# %%
movie_df.head()
# Out:
#   show_id   type                                             title  \
# 0      s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2  Movie                            Ernest Saves Christmas
# 2      s3  Movie                      Ice Age: A Mammoth Christmas
# 3      s4  Movie                        The Queen Family Singalong
# 5      s6  Movie                                 Becoming Cousteau
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 5                         Liz Garbus
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...  United States
# 5              Jacques Yves Cousteau, Vincent Cassel  United States
#
#           date_added  release_year rating duration         Genre  \
# 0  November 26, 2021          2016   TV-G   23 min     Animation
# 1  November 26, 2021          1988     PG   91 min        Comedy
# 2  November 26, 2021          2011   TV-G   23 min     Animation
# 3  November 26, 2021          2021  TV-PG   41 min       Musical
# 5  November 24, 2021          2021  PG-13   94 min  Biographical
#
#                                          description year_add   country_main
# 0   Join Mickey and the gang as they duck the halls!     2021  United States
# 1  Santa Claus passes his magic bag to a new St. ...     2021  United States
# 2          Sid the Sloth is on Santa's naughty list.     2021  United States
# 3               This is real life, not just fantasy!     2021  United States
# 5  An inside look at the legendary life of advent...     2021  United States

# %%
sb.countplot(x="type", data= df, palette="Set2")
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
#number of movies & show
plt.figure(figsize=(12,10))
sb.countplot(x="rating", data= movie_df, palette="Set2", order=movie_df['rating'].value_counts().index[0:15])
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sb.countplot(y="release_year", data= df, palette="cool", order= df['release_year'].value_counts().index[0:15],hue=df['type'])
# Out:
# <Axes: xlabel='count', ylabel='release_year'>

# %%
movie_df['duration']=movie_df['duration'].str.replace(' min','')
movie_df['duration']=movie_df['duration'].astype(str).astype(int)
movie_df['duration']
# Out:
# 0        23
# 1        91
# 2        23
# 3        41
# 5        94
#        ...
# 1445    108
# 1446    106
# 1447    107
# 1448    112
# 1449      2
# Name: duration, Length: 880, dtype: int64

# %%
sb.kdeplot(data=movie_df['duration'], shade=True)
# Out:
# <Axes: xlabel='duration', ylabel='Density'>

# %%
plt.figure(figsize=(15,8))
sb.countplot(x="country_main", data=movie_df, palette="Accent", order=movie_df['country_main'].value_counts().index[0:15])
# Out:
# <Axes: xlabel='country_main', ylabel='count'>

# %%
columns=['Genre','country_main']
gen_country = df[columns]
gen_country.head()
# Out:
#           Genre   country_main
# 0     Animation  United States
# 1        Comedy  United States
# 2     Animation  United States
# 3       Musical  United States
# 5  Biographical  United States

# %%
gen_country['Genre'].value_counts()
# Out:
# Genre
# Action-Adventure    298
# Animation           172
# Comedy              141
# Animals & Nature     73
# Coming of Age        50
# Documentary          49
# Biographical         32
# Drama                23
# Buddy                13
# Family               10
# Concert Film          7
# Fantasy               4
# Crime                 3
# Musical               2
# Dance                 1
# Sports                1
# Anthology             1
# Name: count, dtype: int64

# %%
size = gen_country['Genre'].value_counts()
size
# Out:
# Genre
# Action-Adventure    298
# Animation           172
# Comedy              141
# Animals & Nature     73
# Coming of Age        50
# Documentary          49
# Biographical         32
# Drama                23
# Buddy                13
# Family               10
# Concert Film          7
# Fantasy               4
# Crime                 3
# Musical               2
# Dance                 1
# Sports                1
# Anthology             1
# Name: count, dtype: int64

# %%
pip install squarify
# Out:
# Requirement already satisfied: squarify in /usr/local/lib/python3.10/dist-packages (0.4.4)

# %%
features=['Genre','cast','description','title']
filters = df[features]

# %%
#Cleaning the data by making all the words in lower case.
def clean_data(x):
        return str.lower(x.replace(" ", ""))

# %%
for feature in features:
    filters[feature] = filters[feature].apply(clean_data)

filters.head()
# Out:
#           Genre                                               cast  \
# 0     animation  chrisdiamantopoulos,tonyanselmo,tressmacneille...
# 1        comedy                jimvarney,noelleparker,douglasseale
# 2     animation  raymondalbertromano,johnleguizamo,denisleary,q...
# 3       musical  darrencriss,adamlambert,derekhough,alexanderje...
# 5  biographical                  jacquesyvescousteau,vincentcassel
#
#                                          description  \
# 0            joinmickeyandthegangastheyduckthehalls!
# 1           santaclauspasseshismagicbagtoanewst.nic.
# 2                 sidtheslothisonsanta'snaughtylist.
# 3                     thisisreallife,notjustfantasy!
# 5  aninsidelookatthelegendarylifeofadventurerjacq...
#
#                                        title
# 0  duckthehalls:amickeymousechristmasspecial
# 1                       ernestsaveschristmas
# 2                   iceage:amammothchristmas
# 3                    thequeenfamilysingalong
# 5                           becomingcousteau

# %%
def create_soup(x):
    return x['cast'] + ' ' +x['Genre']+' '+ x['description']

# %%
filters['soup'] = filters.apply(create_soup, axis=1)

# %%
# Import CountVectorizer and create the count matrix
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(filters['soup'])

# %%
# Compute the Cosine Similarity matrix based on the count_matrix
from sklearn.metrics.pairwise import cosine_similarity

cosine_sim2 = cosine_similarity(count_matrix, count_matrix)

# %%
filters.sort_values(by='Genre').head(60)
# Out:
#                  Genre                                               cast  \
# 1449  action-adventure                                       charlietahan
# 461   action-adventure  johnnydepp,javierbardem,brentonthwaites,kayasc...
# 1007  action-adventure  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1008  action-adventure  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 454   action-adventure  craignelson,hollyhunter,sarahvowell,huckleberr...
# 1009  action-adventure  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1010  action-adventure  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1011  action-adventure  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1014  action-adventure  daveighchase,chrissanders,davidstiers,kevinmcd...
# 1020  action-adventure  daveighchase,christophersanders,tiacarrere,dav...
# 441   action-adventure  jakegyllenhaal,benkingsley,gemmaarterton,alfre...
# 1034  action-adventure  deebaker,chloebennet,kathreenkhavari,andrewkis...
# 1037  action-adventure  paulrudd,evangelinelilly,coreystoll,bobbycanna...
# 432   action-adventure  paulrudd,evangelinelilly,michaelpeña,waltongog...
# 1038  action-adventure  robertdowneyjr.,chrishemsworth,markruffalo,chr...
# 1039  action-adventure  robertdowneyjr.,chrisevans,markruffalo,chrishe...
# 998   action-adventure  tessathompson,justintheroux,samelliott,ashleyj...
# 989   action-adventure  christyromano,willfriedle,nancycartwright,tahj...
# 988   action-adventure  sadiestanley,seangiambrone,ciarawilson,tayloro...
# 473   action-adventure  jamesmcavoy,michaelfassbender,jenniferlawrence...
# 500   action-adventure  charlesfleischer,kathleenturner,aprilwinchell,...
# 499   action-adventure  maewhitman,christinahendricks,tomhiddleston,lu...
# 498   action-adventure  billmurray,benkingsley,idriselba,lupitanyong'o...
# 965   action-adventure  steveboyes,dr.steveboyes,chrisboyes,tumeletsos...
# 493   action-adventure  harrisonchad,georgecarlin,bradgarrett,ronperlm...
# 492   action-adventure  tonygoldwyn,minniedriver,glennclose,alexlinz,r...
# 491   action-adventure  robertdowneyjr.,chrishemsworth,markruffalo,chr...
# 1040  action-adventure  chrisevans,robertdowneyjr.,scarlettjohansson,s...
# 970   action-adventure  mackenzieastin,kevinspacey,davidogdenstiers,au...
# 981   action-adventure  patboone,jamesmason,arlenedahl,dianebaker,thay...
# 983   action-adventure  joeylawrence,matthewlawrence,andrewlawrence,su...
# 483   action-adventure  dwaynejohnson,annasophiarobb,carlagugino,ciará...
# 482   action-adventure  rayromano,johnleguizamo,denisleary,adamdevine,...
# 986   action-adventure  shaquilleo'neal,franciscapra,allywalker,jamesa...
# 477   action-adventure  hughjackman,jamesmcavoy,michaelfassbender,jenn...
# 476   action-adventure  aldenehrenreich,woodyharrelson,emiliaclarke,do...
# 973   action-adventure  miriammargolyes,joannalumley,petepostlethwaite...
# 1041  action-adventure  chrisevans,tommyjones,hugoweaving,hayleyatwell...
# 1042  action-adventure  chrisevans,scarlettjohansson,sebastianstan,ant...
# 420   action-adventure  johnnydepp,annehathaway,miawasikowska,mattluca...
# 378   action-adventure  nicolascage,jaybaruchel,alfredmolina,teresapal...
# 1098  action-adventure  timcurry,kevinbishop,billyconnolly,jennifersau...
# 1099  action-adventure  rickygervais,tyburrell,tinafey,stevewhitmire,e...
# 1102  action-adventure  nicolascage,jonvoight,harveykeitel,edharris,di...
# 373   action-adventure  leslienielsen,kellylynch,erniehudson,stephento...
# 1109  action-adventure  joeylawrence,billyjoel,cheechmarin,richardmull...
# 1113  action-adventure  dannyglover,rayliotta,denisleary,dougdoug,cori...
# 1096  action-adventure  ming-nawen,b.d.wong,markmoseley,lucyliu,harvey...
# 1120  action-adventure  brycehoward,oakesfegley,wesbentley,karlurban,o...
# 363   action-adventure  helensadler,omarmiller,jakegreen,kellymarietra...
# 360   action-adventure  danecook,edharris,juliebowen,curtisarmstrong,j...
# 359   action-adventure  danecook,stacykeach,bradgarrett,terihatcher,ju...
# 1122  action-adventure  harrietowen,blayneweaver,coreyburton,jeffbenne...
# 1126  action-adventure  vincentmartella,ashleytisdale,thomasbrodie-san...
# 350   action-adventure  keiraknightley,mackenziefoy,eugenioderbez,jayd...
# 348   action-adventure  kellypreston,lyndacarter,michaelangarano,danie...
# 677   action-adventure  thomaschurch,juliebenz,christinapickles,angusj...
# 501   action-adventure  charlesfleischer,aprilwinchell,louhirsch,corey...
# 1088  action-adventure  auli'icravalho,dwaynejohnson,rachelhouse,temue...
# 386   action-adventure  piperperabo,manolocardona,jamiecurtis,joseyazp...
#
#                                             description  \
# 1449               viewoneofsparky'sfavoritehomemovies.
# 461   captainjacksparrowsearchesforthetridentofposei...
# 1007     theenragedemperorsendsdarthvadertodestroyluke.
# 1008       lukeskywalkerattemptsadaringraidoncoruscant.
# 454   theincrediblesspringintoactionwhenadangerousne...
# 1009    lukeskywalkeraccidentlyopensaremainingholocron.
# 1010  yodaandobi-wanrecallfreeingtheholocronsfromthe...
# 1011                obi-wanurgesluketotraveltotatooine.
# 1014  dr.hamstervielforcesjumbatocreateleroy,theevil...
# 1020  alittlegirladoptsawantedalienwreakinghavoconth...
# 441   arogueprinceandrivalprincesssafeguardamagicald...
# 1034  marvel’syoungpoweredheroesjoinforcestoprotectt...
# 1037  scottlanganddr.hankpymplanaheistthatcouldsavet...
# 432   ant-manandthewaspmustjoinforcestouncoversecret...
# 1038  tonystarkunwittinglycreatesana.i.monsterbenton...
# 1039  theepicfinaletotheinfinitysaga,thisdramaticsho...
# 998   ahousedogandastrayembarkonanadventureandcometo...
# 989   kim'snewcampuscrushdistractsherfromdr.drakken'...
# 988         kimpossibleandronstoppabletakeonhighschool.
# 473   apocalypse,themostpowerfulmutantintheuniverse,...
# 500   rogerrabbitislefttocareforbabyhermaninyellowst...
# 499   tinkerbellandfriendsfacethepiratesofskullrockt...
# 498   aman-cubwho’sbeenraisedbyafamilyofwolveseludes...
# 965   followateamofexplorersonanepicexpeditiontosave...
# 493   youngtarzandecideshisapefamilywouldbebetteroff...
# 492   adoptedbygorillas,tarzan’slifechangesforeverwh...
# 491   theavengersmustbewillingtosacrificealltodefeat...
# 1040  captainamericaandironmanclash,causingtheavenge...
# 970   willcourageouslyjoinsadogsledracethatmaysavehi...
# 981   aprofessorandhiscolleagueengageinaracetoseewho...
# 983   modern-daypiratesleavetwocousinsstrandedonanis...
# 483   alasvegascabdriverhelpstwoaliensdisguisedastee...
# 482   whentheirworldisthreatened,mannyandfriendsgoon...
# 986   12-year-oldmaxconnoraccidentallyfreesa3,000-ye...
# 477   charactersfromthex-mentrilogyjointheiryoungers...
# 476   witnessthebeginningofthestarwarssaga'smostunli...
# 973   ayoungboyescapeshiscruelhomelifewhenhediscover...
# 1041  atop-secretresearchprojectturnssteverogersinto...
# 1042  captainamericaandblackwidowjoinforcesagainstth...
# 420   alicereturnstounderlandtosavethemadhatterinara...
# 378   amodern-daysorcerermustmakehisseeminglyaverage...
# 1098    theclassicpiratetalegetsafunandzanymuppettwist.
# 1099  themuppetsfindthemselvesentangledinaninternati...
# 1102  bengatesmustkidnapthepresidenttoprovehisancest...
# 373   cluelessmr.magoosetsouttogetbackastolenpreciou...
# 1109  afeistyyoungcatexploresnewyorkinthisanimatedsp...
# 1113  soldierssecretlytransportanelephantacross200mi...
# 1096  mulanmustcompleteadangerousmissionbeforemarryi...
# 1120  amysteriousboyclaimstoliveinthewoodswithagiant...
# 363   onthefestivelifeday,reyandbb-8embarkonanepicad...
# 360   airracerdustyteamsupwithadynamiccrewofflyingfi...
# 359   acropdustertakesontheworld’sfastestinthegreate...
# 1122  wendy'sdaughterjaneiswhiskedawaytoneverlandbyc...
# 1126  phineasandferbjumpdimensionsandlearnperryisare...
# 350    fromdisneycomesthereimaginedtaleofthenutcracker.
# 348   ittakesinnerandouterstrengthtomakeanameforyour...
# 677   georgemustrescuehisfamily,thensavethejunglefro...
# 501   rogerrabbitislefttobabysitwiththemischievousba...
# 1088  moanaandmauisetsailonajourneyacrosstheoceantos...
# 386   papihastorescuehistruelove,chloe,whenshegetslo...
#
#                                                   title  \
# 1449                   captainsparkyvs.theflyingsaucers
# 461            piratesofthecaribbean:deadmentellnotales
# 1007  legostarwars:thenewyodachronicles-clashofthesk...
# 1008  legostarwars:thenewyodachronicles-raidoncoruscant
# 454                                        incredibles2
# 1009  legostarwars: thenewyodachronicles–duelofthesk...
# 1010  legostarwars:thenewyodachronicles–escapefromth...
# 1011  legostarwars:thenewyodachronicles–racefortheho...
# 1014                                       leroy&stitch
# 1020                                        lilo&stitch
# 441                       princeofpersia:thesandsoftime
# 1034                        marvelrising:secretwarriors
# 1037                              marvelstudios'ant-man
# 432                     marvelstudios'ant-manandthewasp
# 1038                 marvelstudios'avengers:ageofultron
# 1039                     marvelstudios'avengers:endgame
# 998                                     ladyandthetramp
# 989                         kimpossiblemovie:sothedrama
# 988                                         kimpossible
# 473                                    x-men:apocalypse
# 500                                         trailmix-up
# 499                                      thepiratefairy
# 498                                       thejunglebook
# 965                                     intotheokavango
# 493                                            tarzanii
# 492                                              tarzan
# 491                  marvelstudios'avengers:infinitywar
# 1040              marvelstudios'captainamerica:civilwar
# 970                                            ironwill
# 981                        journeytothecenteroftheearth
# 983                                         jumpingship
# 483                                 racetowitchmountain
# 482                              iceage:collisioncourse
# 986                                              kazaam
# 477                              x-men:daysoffuturepast
# 476                                 solo:astarwarsstory
# 973                               jamesandthegiantpeach
# 1041       marvelstudios'captainamerica:thefirstavenger
# 1042      marvelstudios'captainamerica:thewintersoldier
# 420                         alicethroughthelookingglass
# 378                             thesorcerer'sapprentice
# 1098                               muppettreasureisland
# 1099                                  muppetsmostwanted
# 1102                     nationaltreasure:bookofsecrets
# 373                                            mr.magoo
# 1109                                     oliver&company
# 1113                                 operationdumbodrop
# 1096                                            mulanii
# 1120                                       pete'sdragon
# 363                          legostarwarsholidayspecial
# 360                                  planes:fire&rescue
# 359                                              planes
# 1122                         peterpan:returntoneverland
# 1126       phineasandferbthemovie:acrossthe2nddimension
# 350                       thenutcrackerandthefourrealms
# 348                                             skyhigh
# 677                                  georgeofthejungle2
# 501                                        tummytrouble
# 1088                                              moana
# 386                               beverlyhillschihuahua
#
#                                                    soup
# 1449  charlietahan action-adventure viewoneofsparky'...
# 461   johnnydepp,javierbardem,brentonthwaites,kayasc...
# 1007  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1008  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 454   craignelson,hollyhunter,sarahvowell,huckleberr...
# 1009  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1010  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1011  tomkane,anthonydaniels,mattsloan,trevordevall,...
# 1014  daveighchase,chrissanders,davidstiers,kevinmcd...
# 1020  daveighchase,christophersanders,tiacarrere,dav...
# 441   jakegyllenhaal,benkingsley,gemmaarterton,alfre...
# 1034  deebaker,chloebennet,kathreenkhavari,andrewkis...
# 1037  paulrudd,evangelinelilly,coreystoll,bobbycanna...
# 432   paulrudd,evangelinelilly,michaelpeña,waltongog...
# 1038  robertdowneyjr.,chrishemsworth,markruffalo,chr...
# 1039  robertdowneyjr.,chrisevans,markruffalo,chrishe...
# 998   tessathompson,justintheroux,samelliott,ashleyj...
# 989   christyromano,willfriedle,nancycartwright,tahj...
# 988   sadiestanley,seangiambrone,ciarawilson,tayloro...
# 473   jamesmcavoy,michaelfassbender,jenniferlawrence...
# 500   charlesfleischer,kathleenturner,aprilwinchell,...
# 499   maewhitman,christinahendricks,tomhiddleston,lu...
# 498   billmurray,benkingsley,idriselba,lupitanyong'o...
# 965   steveboyes,dr.steveboyes,chrisboyes,tumeletsos...
# 493   harrisonchad,georgecarlin,bradgarrett,ronperlm...
# 492   tonygoldwyn,minniedriver,glennclose,alexlinz,r...
# 491   robertdowneyjr.,chrishemsworth,markruffalo,chr...
# 1040  chrisevans,robertdowneyjr.,scarlettjohansson,s...
# 970   mackenzieastin,kevinspacey,davidogdenstiers,au...
# 981   patboone,jamesmason,arlenedahl,dianebaker,thay...
# 983   joeylawrence,matthewlawrence,andrewlawrence,su...
# 483   dwaynejohnson,annasophiarobb,carlagugino,ciará...
# 482   rayromano,johnleguizamo,denisleary,adamdevine,...
# 986   shaquilleo'neal,franciscapra,allywalker,jamesa...
# 477   hughjackman,jamesmcavoy,michaelfassbender,jenn...
# 476   aldenehrenreich,woodyharrelson,emiliaclarke,do...
# 973   miriammargolyes,joannalumley,petepostlethwaite...
# 1041  chrisevans,tommyjones,hugoweaving,hayleyatwell...
# 1042  chrisevans,scarlettjohansson,sebastianstan,ant...
# 420   johnnydepp,annehathaway,miawasikowska,mattluca...
# 378   nicolascage,jaybaruchel,alfredmolina,teresapal...
# 1098  timcurry,kevinbishop,billyconnolly,jennifersau...
# 1099  rickygervais,tyburrell,tinafey,stevewhitmire,e...
# 1102  nicolascage,jonvoight,harveykeitel,edharris,di...
# 373   leslienielsen,kellylynch,erniehudson,stephento...
# 1109  joeylawrence,billyjoel,cheechmarin,richardmull...
# 1113  dannyglover,rayliotta,denisleary,dougdoug,cori...
# 1096  ming-nawen,b.d.wong,markmoseley,lucyliu,harvey...
# 1120  brycehoward,oakesfegley,wesbentley,karlurban,o...
# 363   helensadler,omarmiller,jakegreen,kellymarietra...
# 360   danecook,edharris,juliebowen,curtisarmstrong,j...
# 359   danecook,stacykeach,bradgarrett,terihatcher,ju...
# 1122  harrietowen,blayneweaver,coreyburton,jeffbenne...
# 1126  vincentmartella,ashleytisdale,thomasbrodie-san...
# 350   keiraknightley,mackenziefoy,eugenioderbez,jayd...
# 348   kellypreston,lyndacarter,michaelangarano,danie...
# 677   thomaschurch,juliebenz,christinapickles,angusj...
# 501   charlesfleischer,aprilwinchell,louhirsch,corey...
# 1088  auli'icravalho,dwaynejohnson,rachelhouse,temue...
# 386   piperperabo,manolocardona,jamiecurtis,joseyazp...

# %%
# Reset index of our main DataFrame and construct reverse mapping as before
filters=filters.reset_index()
indices = pd.Series(filters.index, index=filters['title'])

# %%
def get_recommendations_new(title, cosine_sim):
    title=title.replace(' ','').lower()
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df['title'].iloc[movie_indices]

# %%
get_recommendations_new('captainsparkyvs.theflyingsaucers', cosine_sim2)
# Out:
# 901                                             Free Solo
# 1181          Sea of Hope: America's Underwater Treasures
# 1176                                  Sanjay's Super Team
# 1407                  Winged Seduction: Birds of Paradise
# 393     The Chronicles Of Narnia: The Voyage of the Da...
# 689                                     Expedition Amelia
# 1431                                  Brave Little Tailor
# 22                                           Get a Horse!
# 74                                            Black Widow
# 130                                        Fantastic Four
# Name: title, dtype: object

# %%
get_recommendations_new('skyhigh', cosine_sim2)
# Out:
# 901                                             Free Solo
# 1449                Captain Sparky vs. The Flying Saucers
# 1181          Sea of Hope: America's Underwater Treasures
# 1176                                  Sanjay's Super Team
# 1407                  Winged Seduction: Birds of Paradise
# 393     The Chronicles Of Narnia: The Voyage of the Da...
# 689                                     Expedition Amelia
# 1431                                  Brave Little Tailor
# 22                                           Get a Horse!
# 74                                            Black Widow
# Name: title, dtype: object

# %%
get_recommendations_new(' Black Widow', cosine_sim2)
# Out:
# 491                Marvel Studios' Avengers: Infinity War
# 1042    Marvel Studios' Captain America: The Winter So...
# 1048                           Marvel Studios' Iron Man 2
# 1050                         Marvel Studios' The Avengers
# 1038              Marvel Studios' Avengers: Age of Ultron
# 1039                    Marvel Studios' Avengers: Endgame
# 1040           Marvel Studios' Captain America: Civil War
# 498                                       The Jungle Book
# 901                                             Free Solo
# 1449                Captain Sparky vs. The Flying Saucers
# Name: title, dtype: object
